# %% [markdown]
# # Save profiles from mulitple files in a netcdf file

# %% [markdown]
# ## All the imports

# %%
import glob

#To deal with data
import xarray as xr

#For basic calculus
import numpy as np
import numpy.ma as ma

# %% [markdown]
# ## Paths to data

# %%
#the path where all data are stored
path_occiput_obs='/mnt/alberta/equipes/IGE/meom/MODEL_SET/ORCA025.L75/ORCA025.L75-OCCITENS/OBS'

# %% [markdown]
# ## Select one argo float in one year file

# %%
#test for one year
path2010=path_occiput_obs+'/OBS-enact_y2010'
one_file2010=path2010+'/ORCA025.L75-OCCITENS.001_y2010_enact_fdbk.nc'
ds_one2010=xr.open_dataset(one_file2010,decode_times=False)

# %%
stations=ds_one2010.STATION_IDENTIFIER
ind=np.where(stations==stations[100])

# %%
stat44032=stations[100]

# %%
print(stations[100].values)
# Out:
# b'44032   '

# %%
len(ind[0])
# Out:
# 2482

# %%
ds_one2010_argo44032=ds_one2010.sel(N_OBS=ind[0])

# %%
ds_one2010_argo44032.to_netcdf("/mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO44032_y2010_r1.nc")

# %%
# !ls -lrth /mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO44032_y2010_r1.nc
# Out:
# -rw-r--r--+ 1 alberta domainusers 26M juil. 13 11:59 /mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO44032_y2010_r1.nc

# %%
ds_clean=ds_one2010_argo44032.drop_vars({'POTM_Hx','PSAL_Hx'})

# %%
ds_clean['POTM_Hx']=POTM_Hx_concat

# %%
ds_clean
# Out:
# <xarray.Dataset>
# Dimensions:               (N_ENTRIES: 1, N_EXTRA: 1, N_LEVELS: 150, N_OBS: 2482, N_QCF: 2, N_VARS: 2, ensemble: 3)
# Dimensions without coordinates: N_ENTRIES, N_EXTRA, N_LEVELS, N_OBS, N_QCF, N_VARS, ensemble
# Data variables: (12/39)
#     VARIABLES             (N_VARS) |S8 b'POTM    ' b'PSAL    '
#     ENTRIES               (N_ENTRIES) |S8 b'Hx      '
#     EXTRA                 (N_EXTRA) |S8 b'TEMP    '
#     STATION_IDENTIFIER    (N_OBS) |S8 b'44032   ' b'44032   ' ... b'44032   '
#     STATION_TYPE          (N_OBS) |S4 b' 741' b' 741' ... b' 741' b' 741'
#     LONGITUDE             (N_OBS) float64 -69.36 -69.36 -69.36 ... -69.36 -69.36
#     ...                    ...
#     PSAL_IOBSI            (N_OBS) int32 875 875 875 875 875 ... 875 875 875 875
#     PSAL_IOBSJ            (N_OBS) int32 698 698 698 698 698 ... 698 698 698 698
#     PSAL_IOBSK            (N_OBS, N_LEVELS) int32 ...
#     PSAL_GRID             |S1 b'T'
#     TEMP                  (N_OBS, N_LEVELS) float32 ...
#     POTM_Hx               (ensemble, N_OBS, N_LEVELS) float32 7.211 ... 1e+05
# Attributes:
#     title:       NEMO observation operator output
#     Convention:  NEMO unified observation operator output

# %% [markdown]
# ## Get all runs for one float and one year

# %%
POTM_Hx1=ds_one2010_argo44032.POTM_Hx
PSAL_Hx1=ds_one2010_argo44032.PSAL_Hx

# %%
file2_2010=path2010+'/ORCA025.L75-OCCITENS.002_y2010_enact_fdbk.nc'
ds2_2010=xr.open_dataset(file2_2010,decode_times=False)
ds2_2010_argo44032=ds2_2010.sel(N_OBS=ind[0]) #exactement les mêmes indices dans tous les fichiers

POTM_Hx2=ds2_2010_argo44032.POTM_Hx
PSAL_Hx2=ds2_2010_argo44032.PSAL_Hx

# %%
POTM_Hx2.shape
# Out:
# (2482, 150)

# %%
POTM_Hx1.shape
# Out:
# (2482, 150)

# %%
POTM_Hx_concat=xr.concat([POTM_Hx1, POTM_Hx2], "ensemble")

# %%
POTM_Hx_concat
# Out:
# <xarray.DataArray 'POTM_Hx' (ensemble: 2, N_OBS: 2482, N_LEVELS: 150)>
# array([[[7.2111998e+00, 7.2112241e+00, 7.1988311e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2060003e+00, 7.2060261e+00, 7.1944013e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.1961279e+00, 7.1961555e+00, 7.1853971e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         ...,
#         [7.2199016e+00, 7.3443279e+00, 7.7435226e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2324319e+00, 7.3462734e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2601757e+00, 7.8661089e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04]],
#
#        [[7.3516583e+00, 7.3516788e+00, 7.3723288e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3456349e+00, 7.3456545e+00, 7.3712792e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3339252e+00, 7.3339505e+00, 7.3673201e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         ...,
#         [7.3845825e+00, 7.4864531e+00, 7.7546635e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4109545e+00, 7.5055666e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4840031e+00, 7.8826032e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04]]], dtype=float32)
# Dimensions without coordinates: ensemble, N_OBS, N_LEVELS
# Attributes:
#     long_name:   Model interpolated potential temperature
#     units:       Degrees centigrade
#     _Fillvalue:  99999.0

# %%
file3_2010=path2010+'/ORCA025.L75-OCCITENS.003_y2010_enact_fdbk.nc'
ds3_2010=xr.open_dataset(file3_2010,decode_times=False)
ds3_2010_argo44032=ds3_2010.sel(N_OBS=ind[0]) #exactement les mêmes indices dans tous les fichiers

POTM_Hx3=ds3_2010_argo44032.POTM_Hx
PSAL_Hx3=ds3_2010_argo44032.PSAL_Hx

# %%
POTM_Hx_concat=xr.concat([POTM_Hx_concat, POTM_Hx3], "ensemble")

# %%
POTM_Hx_concat
# Out:
# <xarray.DataArray 'POTM_Hx' (ensemble: 3, N_OBS: 2482, N_LEVELS: 150)>
# array([[[7.2111998e+00, 7.2112241e+00, 7.1988311e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2060003e+00, 7.2060261e+00, 7.1944013e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.1961279e+00, 7.1961555e+00, 7.1853971e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         ...,
#         [7.2199016e+00, 7.3443279e+00, 7.7435226e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2324319e+00, 7.3462734e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.2601757e+00, 7.8661089e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04]],
#
#        [[7.3516583e+00, 7.3516788e+00, 7.3723288e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3456349e+00, 7.3456545e+00, 7.3712792e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3339252e+00, 7.3339505e+00, 7.3673201e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
# ...
#         [7.3845825e+00, 7.4864531e+00, 7.7546635e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4109545e+00, 7.5055666e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4840031e+00, 7.8826032e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04]],
#
#        [[7.3694477e+00, 7.3694682e+00, 7.3654451e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3632002e+00, 7.3632197e+00, 7.3610620e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.3514757e+00, 7.3515229e+00, 7.3512764e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         ...,
#         [7.3751779e+00, 7.4869704e+00, 7.7635674e+00, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4005246e+00, 7.4968691e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04],
#         [7.4648738e+00, 7.8684535e+00, 9.9999000e+04, ...,
#          9.9999000e+04, 9.9999000e+04, 9.9999000e+04]]], dtype=float32)
# Dimensions without coordinates: ensemble, N_OBS, N_LEVELS
# Attributes:
#     long_name:   Model interpolated potential temperature
#     units:       Degrees centigrade
#     _Fillvalue:  99999.0

# %%
def selec_one_argo_one_year_all_runs(station,year):
    #first run first
    path=path_occiput_obs+'/OBS-enact_y'+str(year)
    file1=path+'/ORCA025.L75-OCCITENS.001_y'+str(year)+'_enact_fdbk.nc'
    ds1=xr.open_dataset(file1,decode_times=False)
    stations=ds1.STATION_IDENTIFIER
    ind=np.where(stations==station)
    ds1_argo_selec=ds1.sel(N_OBS=ind[0]) 

    POTM_Hx_concat=ds1_argo_selec.POTM_Hx
    PSAL_Hx_concat=ds1_argo_selec.PSAL_Hx
    
    #loop on all other years and concatenate
    for k in np.arange(1,50):
        kk="{:03d}".format(k)
        file=path+'/ORCA025.L75-OCCITENS.'+str(kk)+'_y'+str(year)+'_enact_fdbk.nc'
        ds=xr.open_dataset(file,decode_times=False)
        ds_argo_selec=ds.sel(N_OBS=ind[0])
        POTM_Hx=ds_argo_selec.POTM_Hx
        PSAL_Hx=ds_argo_selec.PSAL_Hx
        POTM_Hx_concat=xr.concat([POTM_Hx_concat, POTM_Hx], "ensemble")
        PSAL_Hx_concat=xr.concat([PSAL_Hx_concat, PSAL_Hx], "ensemble")
        
    #replace model data in the first file by the concatenated 50 runs with dimension ensemble
    ds_argo_selec=ds1_argo_selec.drop_vars({'POTM_Hx','PSAL_Hx'})
    ds_argo_selec['POTM_Hx']=POTM_Hx_concat
    ds_argo_selec['PSAL_Hx']=PSAL_Hx_concat
    
    #write on disk
    stat=str(station.values)
    str_stat=stat[2:7]
    ds_argo_selec.to_netcdf('/mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO'+str(str_stat)+'_y'+str(year)+'_r1-50.nc')

# %%
selec_one_argo_one_year_all_runs(stat44032,2011)

# %%
# !ls -lrth /mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO44032_y2011_r1-50.nc
# Out:
# -rw-r--r--+ 1 alberta domainusers 192M juil. 13 12:53 /mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO44032_y2011_r1-50.nc

# %%
print(str(stat44032.values))
# Out:
# b'44032   '

# %%
str44032=str(stat44032.values)

# %%
print(str44032[2:7])
# Out:
# 44032

# %%
def selec_one_argo_one_year_all_runs(station,year):
    #first run first
    path=path_occiput_obs+'/OBS-enact_y'+str(year)
    file1=path+'/ORCA025.L75-OCCITENS.001_y'+str(year)+'_enact_fdbk.nc'
    ds1=xr.open_dataset(file1,decode_times=False)
    stations=ds1.STATION_IDENTIFIER
    ind=np.where(stations==station)
    ds1_argo_selec=ds1.sel(N_OBS=ind[0]) 

    POTM_Hx_concat=ds1_argo_selec.POTM_Hx
    PSAL_Hx_concat=ds1_argo_selec.PSAL_Hx
    
    #loop on all other years and concatenate
    for k in np.arange(1,50):
        kk="{:03d}".format(k)
        file=path+'/ORCA025.L75-OCCITENS.'+str(kk)+'_y'+str(year)+'_enact_fdbk.nc'
        ds=xr.open_dataset(file,decode_times=False)
        ds_argo_selec=ds.sel(N_OBS=ind[0])
        POTM_Hx=ds_argo_selec.POTM_Hx
        PSAL_Hx=ds_argo_selec.PSAL_Hx
        POTM_Hx_concat=xr.concat([POTM_Hx_concat, POTM_Hx], "ensemble")
        PSAL_Hx_concat=xr.concat([PSAL_Hx_concat, PSAL_Hx], "ensemble")
        
    #replace model data in the first file by the concatenated 50 runs with dimension ensemble
    ds_argo_selec=ds1_argo_selec.drop_vars({'POTM_Hx','PSAL_Hx'})
    ds_argo_selec['POTM_Hx']=POTM_Hx_concat
    ds_argo_selec['PSAL_Hx']=PSAL_Hx_concat
    return ds_argo_selec
    
    
def selec_one_argo_years_all_runs(station,year1,year2):
    #first year first
    ds_concat=selec_one_argo_one_year_all_runs(station,year1)
    #loop on the other years
    for year in np.arange(year1+1,year2+1):
        ds=selec_one_argo_one_year_all_runs(station,year)
        ds_concat=xr.concat([ds_concat,ds],dim='N_OBS')
        
    #write on disk
    stat=str(station.values)
    str_stat=stat[2:7]
    ds_concat.to_netcdf('/mnt/alberta/equipes/IGE/meom/workdir/alberta/ARGO/selec_profiles/ARGO'+str(str_stat)+'_y'+str(year1)+'-'+str(year2)+'_r1-50.nc')

# %%
## 2010 à 2012 150 niveaux verticaux et de 2013 à 2015 400

# %%
# %%time
selec_one_argo_years_all_runs(stat44032,2010,2012)
# Out:
# CPU times: user 1min 53s, sys: 25.8 s, total: 2min 19s
# Wall time: 8min 44s

# %%
# %%time
selec_one_argo_years_all_runs(stat44032,2013,2015)
